# %%
import pandas as pd
# Reading a csv file
csvData=pd.read_csv("C:\\Users\\Admin\\Downloads\\weather.csv")
csvData
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
excelData=pd.read_excel("C:\\Users\\Admin\\Downloads\\FSI-2023-DOWNLOAD.xlsx")
# Reading a excel file 
excelData
# Out:
#                        Country  Year   Rank  Total  S1: Demographic Pressures  \
# 0                      Somalia  2023    1st  111.9                       10.0
# 1                        Yemen  2023    2nd  108.9                        9.6
# 2                  South Sudan  2023    3rd  108.5                        9.7
# 3    Congo Democratic Republic  2023    4th  107.2                        9.7
# 4                        Syria  2023    5th  107.1                        7.4
# ..                         ...   ...    ...    ...                        ...
# 174                Switzerland  2023  175th   17.8                        2.4
# 175                New Zealand  2023  176th   16.7                        1.1
# 176                    Finland  2023  177th   16.0                        1.7
# 177                    Iceland  2023  178th   15.7                        1.5
# 178                     Norway  2023  179th   14.5                        1.4
#
# ...

# %%
# this is a python dictionary that contains weather data
weather_data = {
    "location": "New York",
    "date": "2024-10-17",
    "temperature": {
        "avg_temp": 22.5,
        "max_temp": 25.0,
        "min_temp": 20.0
    },
    "humidity": 60,
    "precipitation": 12.3,
    "wind": {
        "speed": 10,
        "direction": "NE"
    },
    "forecast": "Partly Cloudy"
}
# here we are creating a Data frame through python dictionary

pythonData=pd.DataFrame(weather_data)
pythonData
# Out:
#            location        date  temperature  humidity  precipitation wind  \
# avg_temp   New York  2024-10-17         22.5        60           12.3  NaN
# max_temp   New York  2024-10-17         25.0        60           12.3  NaN
# min_temp   New York  2024-10-17         20.0        60           12.3  NaN
# speed      New York  2024-10-17          NaN        60           12.3   10
# direction  New York  2024-10-17          NaN        60           12.3   NE
#
#                 forecast
# avg_temp   Partly Cloudy
# max_temp   Partly Cloudy
# min_temp   Partly Cloudy
# speed      Partly Cloudy
# direction  Partly Cloudy

# %%
weather_data = (
    (
        "New York",
        "2024-10-17",
        60,
        12.3,
    ),
    (
        "Los Angeles",
        "2024-10-17",
        50,
        5.0,
    )
)

# Creating data frame and giving column name to each of the columns 

tupleData=pd.DataFrame(weather_data,columns=["City","Day","Avg_temp","Loweset_Temp"])
tupleData
# Out:
#           City         Day  Avg_temp  Loweset_Temp
# 0     New York  2024-10-17        60          12.3
# 1  Los Angeles  2024-10-17        50           5.0
