# %%
import pandas as pd
dataFrame = pd.read_csv("C:\\Users\\Admin\\Downloads\\weather.csv")
dataFrame
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
rows,columns=dataFrame.shape #it will allow us to access no. of rows and columns

# %%
rows #getting no. of rows

# %%
columns# geeting no. of columns

# %%
dataFrame.head(10) #accessing 10 rows from the top

# %%
dataFrame.tail(10)# accessing 10 rows from bottom

# %%
dataFrame[10:21] #it will print rows from 10-20

# %%
dataFrame.columns #it will print no. of columns
# Out:
# Index(['Data.Precipitation', 'Date.Full', 'Date.Month', 'Date.Week of',
#        'Date.Year', 'Station.City', 'Station.Code', 'Station.Location',
#        'Station.State', 'Data.Temperature.Avg Temp',
#        'Data.Temperature.Max Temp', 'Data.Temperature.Min Temp',
#        'Data.Wind.Direction', 'Data.Wind.Speed'],
#       dtype='object')

# %%
dataFrame['Station.City'] #it will print the all the data of this columns
# here the column name is in dot format that's why accessing it through brackets.
# but suppose column name was only dateFull then we can access it by dataFrame.datezFull and also in bracket form as well

# %%
type(dataFrame['Station.City']) # it will tell type of a columns
# Out:
# pandas.core.series.Series

# %%
# If i want to print only few columns then i can use
dataFrame[['Date.Full','Station.City']]

# %%
# to find max/min from a column

dataFrame['Data.Wind.Speed'].max() #tell us the max wind speed
# Out:
# np.float64(6.3298202233769345)

# %%
dataFrame['Data.Wind.Speed'].min() #tell us the min of wind speed
# Out:
# np.float64(0.0)

# %%
dataFrame['Data.Wind.Speed'].mean() #tell us the avg of wind speed
# Out:
# np.float64(6.3298202233769345)

# %%
dataFrame.describe() #tell us the statics of all the columns with integer data types
# Out:
#        Data.Precipitation    Date.Month  Date.Week of     Date.Year  \
# count        16743.000000  16743.000000  16743.000000  16743.000000
# mean             0.579090      6.343128     15.650242   2016.018933
# std              0.988057      3.490723      8.923425      0.136294
# min              0.000000      1.000000      1.000000   2016.000000
# 25%              0.000000      3.000000      8.000000   2016.000000
# 50%              0.190000      6.000000     16.000000   2016.000000
# 75%              0.750000      9.000000     24.000000   2016.000000
# max             20.890000     12.000000     31.000000   2017.000000
#
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# count               16743.000000               16743.000000
# mean                   56.089112                  66.042406
# std                    18.798295                  19.787954
# min                   -27.000000                 -19.000000
# ...

# %%
dataFrame[dataFrame['Data.Temperature.Avg Temp'] >= 30] #perfomring kind of filtiring just similar to sql it will return only those column whose avg temp is greater  equal 30
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16731                1.03  2017-01-01           1             1       2017
# 16732                1.15  2017-01-01           1             1       2017
# 16733                0.61  2017-01-01           1             1       2017
# 16737                0.15  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location  Station.State  \
# ...
